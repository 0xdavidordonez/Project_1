# %%
# Import Pandas and NumPy libraries
import pandas as pd

# Import external library
from pathlib import Path

# Use the pathlib library to set the Path
Main_exchanges_futures = Path("Resources/Main_exchanges_futures.csv")

# %%
# Read CSV without setting a header
mainEXG_df = pd.read_csv(Main_exchanges_futures) 
mainEXG_df.head()
# Out:
#       Unnamed: 0 Open interest Unnamed: 2 Unnamed: 3  Daily average turnover  \
# 0            NaN      Dec 2014   Dec 2015   Mar 2016                  2014.0
# 1        Futures           NaN        NaN        NaN                     NaN
# 2    All markets         25580      25092      25447                  5047.0
# 3  Interest rate         25346      24857      25210                  4934.0
# 4     short-term         23736      23315      23588                  4291.0
#
#    Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ...  \
# 0      2015.0   Nov 2015   Dec 2015   Jan 2016   Feb 2016  ...
# 1         NaN        NaN        NaN        NaN        NaN  ...
# 2      4572.0       4246       4408       5331       5774  ...
# 3      4463.0       4162       4295       5227       5661  ...
# 4      3863.0       3529       3756       4688       4879  ...
#
#   Open interest.6 Unnamed: 62 Unnamed: 63 Daily average turnover.6  \
# 0        Dec 2022    Jun 2023    Sep 2023                   2021.0
# 1             NaN         NaN         NaN                      NaN
# 2           36540       37279       36252                   5863.0
# 3           36220       36951       35934                   5723.0
# 4           33607       33776       32583                   4836.0
#
#    Unnamed: 65  Unnamed: 66 Unnamed: 67 Unnamed: 68 Unnamed: 69 Unnamed: 70
# 0       2022.0     May 2023    Jun 2023    Jul 2023    Aug 2023    Sep 2023
# 1          NaN          NaN         NaN         NaN         NaN         NaN
# 2       8045.0         9856        9240        7315        8163        8468
# 3       7892.0         9724        9090        7180        8030        8300
# 4       6952.0         8553        8152        6397        6817        7340
#
# [5 rows x 71 columns]

# %%
# Read CSV and set the header
mainEXG = pd.read_csv(Main_exchanges_futures) 
mainEXG.head()
# Out:
#       Unnamed: 0 Open interest Unnamed: 2 Unnamed: 3  Daily average turnover  \
# 0            NaN      Dec 2014   Dec 2015   Mar 2016                  2014.0
# 1        Futures           NaN        NaN        NaN                     NaN
# 2    All markets         25580      25092      25447                  5047.0
# 3  Interest rate         25346      24857      25210                  4934.0
# 4     short-term         23736      23315      23588                  4291.0
#
#    Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ...  \
# 0      2015.0   Nov 2015   Dec 2015   Jan 2016   Feb 2016  ...
# 1         NaN        NaN        NaN        NaN        NaN  ...
# 2      4572.0       4246       4408       5331       5774  ...
# 3      4463.0       4162       4295       5227       5661  ...
# 4      3863.0       3529       3756       4688       4879  ...
#
#   Open interest.6 Unnamed: 62 Unnamed: 63 Daily average turnover.6  \
# 0        Dec 2022    Jun 2023    Sep 2023                   2021.0
# 1             NaN         NaN         NaN                      NaN
# 2           36540       37279       36252                   5863.0
# 3           36220       36951       35934                   5723.0
# 4           33607       33776       32583                   4836.0
#
#    Unnamed: 65  Unnamed: 66 Unnamed: 67 Unnamed: 68 Unnamed: 69 Unnamed: 70
# 0       2022.0     May 2023    Jun 2023    Jul 2023    Aug 2023    Sep 2023
# 1          NaN          NaN         NaN         NaN         NaN         NaN
# 2       8045.0         9856        9240        7315        8163        8468
# 3       7892.0         9724        9090        7180        8030        8300
# 4       6952.0         8553        8152        6397        6817        7340
#
# [5 rows x 71 columns]

# %%
# Read CSV and set formatted `Date` column as index 
sp500_df = pd.read_csv(
    Main_exchanges_futures, index_col="Date", infer_datetime_format=True, parse_dates=True
)
mainEXG_df.head()
# Out:
# C:\Users\equit\AppData\Local\Temp\ipykernel_1748\4149476513.py:2: FutureWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   sp500_df = pd.read_csv(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 2
#       1 # Read CSV and set formatted `Date` column as index
# ----> 2 sp500_df = pd.read_csv(
#       3     Main_exchanges_futures, index_col="Date", infer_datetime_format=True, parse_dates=True
#       4 )
#       5 mainEXG_df.head()
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:948, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     944     dtype_backend=dtype_backend,
#     945 )
#     946 kwds.update(kwds_defaults)
# --> 948 return _read(filepath_or_buffer, kwds)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:611, in _read(filepath_or_buffer, kwds)
#     608 _validate_names(kwds.get("names", None))
#     610 # Create the parser.
# --> 611 parser = TextFileReader(filepath_or_buffer, **kwds)
#     613 if chunksize or iterator:
#     614     return parser
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1448, in TextFileReader.__init__(self, f, engine, **kwds)
#    1445     self.options["has_index_names"] = kwds["has_index_names"]
#    1447 self.handles: IOHandles | None = None
# -> 1448 self._engine = self._make_engine(f, self.engine)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1723, in TextFileReader._make_engine(self, f, engine)
#    1720     raise ValueError(msg)
#    1722 try:
# -> 1723     return mapping[engine](f, **self.options)
#    1724 except Exception:
#    1725     if self.handles is not None:
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\c_parser_wrapper.py:162, in CParserWrapper.__init__(self, src, **kwds)
#     160 # error: Cannot determine type of 'names'
#     161 self._validate_parse_dates_presence(self.names)  # type: ignore[has-type]
# --> 162 self._set_noconvert_columns()
#     164 # error: Cannot determine type of 'names'
#     165 self.orig_names = self.names  # type: ignore[has-type]
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\c_parser_wrapper.py:215, in CParserWrapper._set_noconvert_columns(self)
#     213 col_indices = [names_dict[x] for x in self.names]  # type: ignore[has-type]
#     214 # error: Cannot determine type of 'names'
# --> 215 noconvert_columns = self._set_noconvert_dtype_columns(
#     216     col_indices,
#     217     self.names,  # type: ignore[has-type]
#     218 )
#     219 for col in noconvert_columns:
#     220     self._reader.set_noconvert(col)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\base_parser.py:663, in ParserBase._set_noconvert_dtype_columns(self, col_indices, names)
#     661 if isinstance(self.index_col, list):
#     662     for k in self.index_col:
# --> 663         noconvert_columns.add(_set(k))
#     664 elif self.index_col is not None:
#     665     noconvert_columns.add(_set(self.index_col))
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\base_parser.py:640, in ParserBase._set_noconvert_dtype_columns.<locals>._set(x)
#     637     x = usecols[x]
#     639 if not is_integer(x):
# --> 640     x = col_indices[names.index(x)]
#     642 return x
#
# ValueError: 'Date' is not in list

# %%
# Read in another CSV
amd_csv_path = Path("Resources/OTC foreign exchange instruments, by currency.csv") 
amd_df = pd.read_csv(
    OTC foreign exchange instruments, by currency, index_col="Date", infer_datetime_format=True, parse_dates=True
)

# Use the `concat` function to combine the two DataFrames by matching indexes (or in this case `Month`)
combined_df = pd.concat([amd_df, sp500_df], axis="columns", join="inner")

# Rename columns
combined_df.columns = ['AMD', 'SP500']
combined_df.head()
# Out:
#   Cell In[11], line 4
#     OTC foreign exchange instruments, by currency, index_col="Date", infer_datetime_format=True, parse_dates=True
#     ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
# Use the `corr` function to calculate correlations
correlation = combined_df.corr()

# %%
# Use the `pct_change` function to calculate daily returns of closing prices for each column
combined_daily_returns = combined_df.pct_change()
combined_daily_returns.head()

# %%
# Calculate variance of all daily returns of AMD vs. S&P 500
variance = combined_daily_returns['SP500'].var()
variance

# %%
# Calculate beta of all daily returns of AMD
amd_beta = covariance / variance
amd_beta

# %%
# Use the `plot` function to visualize daily portfolio returns
cumulative_portfolio_returns.plot()
